# %%
# for the learning and the referencing
# https://hevodata.com/learn/python-dag-airflow/
# https://airflow.apache.org/docs/apache-airflow/stable/core-concepts/dags.html
# https://airflow.apache.org/docs/apache-airflow/stable/start.html

# %%
# put this in a .py file so it doesnt tie up the notebook.....
try:
    import apacheairflow as aa
    
except:
    # !pip install apache-airflow
    # !airflow standalone
finally:
    print('Boats and hoes')
# Out:
# ...
# standalone | Starting Airflow Standalone
# standalone | Checking database is initialized
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running stamp_revision  -> 290244fb8b83
# WARNI [airflow.models.crypto] empty cryptography key - values will not be stored encrypted.
# standalone | Database ready
# [2023-02-21 14:58:24,487] {manager.py:243} INFO - Inserted Role: Admin
# [2023-02-21 14:58:24,489] {manager.py:243} INFO - Inserted Role: Public
# [2023-02-21 14:58:24,491] {manager.py:824} WARNING - No user yet created, use flask fab command to do it.
# [2023-02-21 14:58:24,506] {manager.py:504} INFO - Created Permission View: can edit on Passwords
# [2023-02-21 14:58:24,508] {manager.py:562} INFO - Added Permission can edit on Passwords to role Admin
# [2023-02-21 14:58:24,511] {manager.py:504} INFO - Created Permission View: can read on Passwords
# ...

# %%
import apache
